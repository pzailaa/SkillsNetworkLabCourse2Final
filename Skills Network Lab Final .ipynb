# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Patrick Z__ <br>
# Engineer

# %% [markdown]
# <i> I am interested in data science because data is power </i>

# %% [markdown]
# ### The code generates a random list of 5 integers between 1 and 3

# %%
import random
randomlist = []
for i in range(0,5):
    n = random.randint(1,30)
    randomlist.append(n)
print(randomlist)
# Out:
# [17, 6, 14, 9, 27]

# %% [markdown]
# <a> Link to Coursera Website </a> <br>
# * Cats
# * Are
# * The best!!!
#
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)
